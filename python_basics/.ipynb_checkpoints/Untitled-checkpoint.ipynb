# %%
print("hello world")
# Out:
# hello world

# %%
name = "Ahsan"
age = 19
city = "Karachi"

print (name, age, city)
# Out:
# Ahsan 19 Karachi

# %%
a = 19
b = 22
c = a + b #Addition
d = a - b #Subtraction
e = a * b #Multiplication

# %%
 print (c, d, e) #in next cell
# Out:
# 41 -3 418

# %%
ahsan_is_hungry = true
if (ahsan_is_hungry) == true:
print("ahsan is hungry")
else:
print("ahsan is not hungry")
# Out:
#   Cell In[38], line 3
#     print("ahsan_is_hungry")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2
